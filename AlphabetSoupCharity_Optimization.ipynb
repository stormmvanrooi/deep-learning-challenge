# %% [markdown]
# <a href="https://colab.research.google.com/github/stormmvanrooi/deep-learning-challenge/blob/branch001/AlphabetSoupCharity_Optimization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("../content/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME  ... ASK_AMT IS_SUCCESSFUL
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB  ...    5000             1
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR  ...  108590             1
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS  ...    5000             0
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION  ...    6692             1
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT  ...  142590             1
#
# [5 rows x 12 columns]

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns = ['EIN', 'NAME', 'ORGANIZATION'])

# %%
# Determine the number of unique values in each column.
for x in application_df.columns:
    print(x, len(application_df[x].unique()))
# Out:
# APPLICATION_TYPE 17
# AFFILIATION 6
# CLASSIFICATION 71
# USE_CASE 5
# STATUS 2
# INCOME_AMT 9
# SPECIAL_CONSIDERATIONS 2
# ASK_AMT 8747
# IS_SUCCESSFUL 2

# %%
# Look at APPLICATION_TYPE value counts for binning

bins = application_df['APPLICATION_TYPE'].value_counts()
bins
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = list(bins[bins<700].index)
application_types_to_replace

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# Other      804
# T8         737
# T7         725
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
bin_counts = application_df['CLASSIFICATION'].value_counts()

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
count_class = bin_counts[bin_counts>1]
count_class
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list (bin_counts[bin_counts<100].index)
classifications_to_replace

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# Other      669
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_df = pd.get_dummies(application_df,dtype=float)
application_df.head()
# Out:
#    STATUS  ASK_AMT  ...  SPECIAL_CONSIDERATIONS_N  SPECIAL_CONSIDERATIONS_Y
# 0       1     5000  ...                       1.0                       0.0
# 1       1   108590  ...                       1.0                       0.0
# 2       1     5000  ...                       1.0                       0.0
# 3       1     6692  ...                       1.0                       0.0
# 4       1   142590  ...                       1.0                       0.0
#
# [5 rows x 45 columns]

# %%
# Split our preprocessed data into our features and target arrays
y = application_df['IS_SUCCESSFUL'].values
y
# Out:
# array([1, 1, 0, ..., 0, 1, 0])

# %%
X = application_df.drop('IS_SUCCESSFUL', axis=1).values
X
# Out:
# array([[1.0000000e+00, 5.0000000e+03, 1.0000000e+00, ..., 0.0000000e+00,
#         1.0000000e+00, 0.0000000e+00],
#        [1.0000000e+00, 1.0859000e+05, 0.0000000e+00, ..., 0.0000000e+00,
#         1.0000000e+00, 0.0000000e+00],
#        [1.0000000e+00, 5.0000000e+03, 0.0000000e+00, ..., 0.0000000e+00,
#         1.0000000e+00, 0.0000000e+00],
#        ...,
#        [1.0000000e+00, 5.0000000e+03, 0.0000000e+00, ..., 0.0000000e+00,
#         1.0000000e+00, 0.0000000e+00],
#        [1.0000000e+00, 5.0000000e+03, 0.0000000e+00, ..., 0.0000000e+00,
#         1.0000000e+00, 0.0000000e+00],
#        [1.0000000e+00, 3.6500179e+07, 0.0000000e+00, ..., 0.0000000e+00,
#         1.0000000e+00, 0.0000000e+00]])

# %%
# Split the preprocessed data into a training and testing dataset

X_train, X_test, y_train, y_test = train_test_split(X,y,random_state = 42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len( X_train_scaled[0])
hidden_nodes_layer1=10
hidden_nodes_layer2=15
hidden_nodes_layer3=20

nn_model= tf.keras.models.Sequential()

# First hidden layer
nn_model.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation='relu'))

# Second hidden layer
nn_model.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation='relu'))

# Output layer
nn_model.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 10)                450
#
#  dense_4 (Dense)             (None, 15)                165
#
#  dense_5 (Dense)             (None, 1)                 16
#
# =================================================================
# Total params: 631
# Trainable params: 631
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn_model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics=['accuracy'])

# %%
# Train the model
fit_model = nn_model.fit(X_train_scaled,y_train,validation_split=0.15, epochs=100)
# Out:
# Epoch 1/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.6123 - accuracy: 0.6829 - val_loss: 0.5598 - val_accuracy: 0.7302
# Epoch 2/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5670 - accuracy: 0.7223 - val_loss: 0.5528 - val_accuracy: 0.7331
# Epoch 3/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5629 - accuracy: 0.7244 - val_loss: 0.5521 - val_accuracy: 0.7354
# Epoch 4/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.5609 - accuracy: 0.7252 - val_loss: 0.5523 - val_accuracy: 0.7354
# Epoch 5/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5600 - accuracy: 0.7243 - val_loss: 0.5519 - val_accuracy: 0.7354
# Epoch 6/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5592 - accuracy: 0.7261 - val_loss: 0.5522 - val_accuracy: 0.7352
# Epoch 7/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5584 - accuracy: 0.7268 - val_loss: 0.5514 - val_accuracy: 0.7357
# Epoch 8/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5579 - accuracy: 0.7261 - val_loss: 0.5508 - val_accuracy: 0.7357
# Epoch 9/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5576 - accuracy: 0.7254 - val_loss: 0.5511 - val_accuracy: 0.7370
# Epoch 10/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5573 - accuracy: 0.7277 - val_loss: 0.5512 - val_accuracy: 0.7357
# Epoch 11/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5565 - accuracy: 0.7281 - val_loss: 0.5516 - val_accuracy: 0.7359
# Epoch 12/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.5560 - accuracy: 0.7277 - val_loss: 0.5508 - val_accuracy: 0.7375
# Epoch 13/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5562 - accuracy: 0.7273 - val_loss: 0.5531 - val_accuracy: 0.7362
# Epoch 14/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5556 - accuracy: 0.7281 - val_loss: 0.5519 - val_accuracy: 0.7365
# Epoch 15/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5559 - accuracy: 0.7271 - val_loss: 0.5506 - val_accuracy: 0.7375
# Epoch 16/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5552 - accuracy: 0.7287 - val_loss: 0.5506 - val_accuracy: 0.7354
# Epoch 17/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5552 - accuracy: 0.7268 - val_loss: 0.5523 - val_accuracy: 0.7378
# Epoch 18/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5550 - accuracy: 0.7277 - val_loss: 0.5516 - val_accuracy: 0.7362
# Epoch 19/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5551 - accuracy: 0.7279 - val_loss: 0.5517 - val_accuracy: 0.7370
# Epoch 20/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5544 - accuracy: 0.7280 - val_loss: 0.5520 - val_accuracy: 0.7378
# Epoch 21/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5547 - accuracy: 0.7277 - val_loss: 0.5519 - val_accuracy: 0.7354
# Epoch 22/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.5547 - accuracy: 0.7285 - val_loss: 0.5510 - val_accuracy: 0.7370
# Epoch 23/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5542 - accuracy: 0.7292 - val_loss: 0.5522 - val_accuracy: 0.7362
# Epoch 24/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5540 - accuracy: 0.7291 - val_loss: 0.5500 - val_accuracy: 0.7375
# Epoch 25/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5540 - accuracy: 0.7282 - val_loss: 0.5521 - val_accuracy: 0.7372
# Epoch 26/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5538 - accuracy: 0.7292 - val_loss: 0.5508 - val_accuracy: 0.7367
# Epoch 27/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5542 - accuracy: 0.7299 - val_loss: 0.5517 - val_accuracy: 0.7370
# Epoch 28/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5538 - accuracy: 0.7287 - val_loss: 0.5519 - val_accuracy: 0.7365
# Epoch 29/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5537 - accuracy: 0.7293 - val_loss: 0.5515 - val_accuracy: 0.7375
# Epoch 30/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5536 - accuracy: 0.7291 - val_loss: 0.5511 - val_accuracy: 0.7365
# Epoch 31/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5536 - accuracy: 0.7294 - val_loss: 0.5514 - val_accuracy: 0.7357
# Epoch 32/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5532 - accuracy: 0.7280 - val_loss: 0.5511 - val_accuracy: 0.7344
# Epoch 33/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5536 - accuracy: 0.7282 - val_loss: 0.5507 - val_accuracy: 0.7370
# Epoch 34/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5531 - accuracy: 0.7292 - val_loss: 0.5524 - val_accuracy: 0.7365
# Epoch 35/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5529 - accuracy: 0.7288 - val_loss: 0.5515 - val_accuracy: 0.7362
# Epoch 36/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5531 - accuracy: 0.7289 - val_loss: 0.5508 - val_accuracy: 0.7370
# Epoch 37/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5528 - accuracy: 0.7292 - val_loss: 0.5521 - val_accuracy: 0.7383
# Epoch 38/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5531 - accuracy: 0.7294 - val_loss: 0.5529 - val_accuracy: 0.7380
# Epoch 39/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5529 - accuracy: 0.7290 - val_loss: 0.5504 - val_accuracy: 0.7370
# Epoch 40/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5527 - accuracy: 0.7295 - val_loss: 0.5506 - val_accuracy: 0.7385
# Epoch 41/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5524 - accuracy: 0.7292 - val_loss: 0.5504 - val_accuracy: 0.7354
# Epoch 42/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5526 - accuracy: 0.7290 - val_loss: 0.5506 - val_accuracy: 0.7365
# Epoch 43/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5527 - accuracy: 0.7292 - val_loss: 0.5497 - val_accuracy: 0.7378
# Epoch 44/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5525 - accuracy: 0.7301 - val_loss: 0.5500 - val_accuracy: 0.7357
# Epoch 45/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5520 - accuracy: 0.7303 - val_loss: 0.5498 - val_accuracy: 0.7362
# Epoch 46/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5522 - accuracy: 0.7289 - val_loss: 0.5519 - val_accuracy: 0.7370
# Epoch 47/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5524 - accuracy: 0.7299 - val_loss: 0.5514 - val_accuracy: 0.7365
# Epoch 48/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5523 - accuracy: 0.7292 - val_loss: 0.5499 - val_accuracy: 0.7357
# Epoch 49/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5522 - accuracy: 0.7305 - val_loss: 0.5513 - val_accuracy: 0.7372
# Epoch 50/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5523 - accuracy: 0.7288 - val_loss: 0.5516 - val_accuracy: 0.7375
# Epoch 51/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5522 - accuracy: 0.7290 - val_loss: 0.5514 - val_accuracy: 0.7375
# Epoch 52/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5522 - accuracy: 0.7287 - val_loss: 0.5507 - val_accuracy: 0.7380
# Epoch 53/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5522 - accuracy: 0.7297 - val_loss: 0.5521 - val_accuracy: 0.7365
# Epoch 54/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5520 - accuracy: 0.7292 - val_loss: 0.5514 - val_accuracy: 0.7370
# Epoch 55/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5519 - accuracy: 0.7296 - val_loss: 0.5512 - val_accuracy: 0.7367
# Epoch 56/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5521 - accuracy: 0.7283 - val_loss: 0.5506 - val_accuracy: 0.7365
# Epoch 57/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5520 - accuracy: 0.7291 - val_loss: 0.5534 - val_accuracy: 0.7365
# Epoch 58/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5515 - accuracy: 0.7291 - val_loss: 0.5510 - val_accuracy: 0.7365
# Epoch 59/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5516 - accuracy: 0.7305 - val_loss: 0.5514 - val_accuracy: 0.7359
# Epoch 60/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5519 - accuracy: 0.7286 - val_loss: 0.5515 - val_accuracy: 0.7367
# Epoch 61/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5517 - accuracy: 0.7302 - val_loss: 0.5511 - val_accuracy: 0.7378
# Epoch 62/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5517 - accuracy: 0.7286 - val_loss: 0.5490 - val_accuracy: 0.7370
# Epoch 63/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5513 - accuracy: 0.7298 - val_loss: 0.5507 - val_accuracy: 0.7352
# Epoch 64/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5514 - accuracy: 0.7300 - val_loss: 0.5500 - val_accuracy: 0.7359
# Epoch 65/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5517 - accuracy: 0.7292 - val_loss: 0.5511 - val_accuracy: 0.7372
# Epoch 66/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5514 - accuracy: 0.7309 - val_loss: 0.5517 - val_accuracy: 0.7359
# Epoch 67/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5517 - accuracy: 0.7295 - val_loss: 0.5515 - val_accuracy: 0.7378
# Epoch 68/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5514 - accuracy: 0.7301 - val_loss: 0.5510 - val_accuracy: 0.7388
# Epoch 69/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5513 - accuracy: 0.7299 - val_loss: 0.5510 - val_accuracy: 0.7370
# Epoch 70/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5512 - accuracy: 0.7294 - val_loss: 0.5516 - val_accuracy: 0.7370
# Epoch 71/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5512 - accuracy: 0.7299 - val_loss: 0.5527 - val_accuracy: 0.7380
# Epoch 72/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5515 - accuracy: 0.7286 - val_loss: 0.5511 - val_accuracy: 0.7370
# Epoch 73/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5509 - accuracy: 0.7287 - val_loss: 0.5528 - val_accuracy: 0.7378
# Epoch 74/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5517 - accuracy: 0.7302 - val_loss: 0.5491 - val_accuracy: 0.7362
# Epoch 75/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5516 - accuracy: 0.7305 - val_loss: 0.5511 - val_accuracy: 0.7372
# Epoch 76/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5510 - accuracy: 0.7309 - val_loss: 0.5502 - val_accuracy: 0.7372
# Epoch 77/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5512 - accuracy: 0.7298 - val_loss: 0.5504 - val_accuracy: 0.7370
# Epoch 78/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5515 - accuracy: 0.7293 - val_loss: 0.5516 - val_accuracy: 0.7367
# Epoch 79/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5509 - accuracy: 0.7298 - val_loss: 0.5526 - val_accuracy: 0.7352
# Epoch 80/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5509 - accuracy: 0.7293 - val_loss: 0.5518 - val_accuracy: 0.7362
# Epoch 81/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5511 - accuracy: 0.7295 - val_loss: 0.5515 - val_accuracy: 0.7357
# Epoch 82/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5509 - accuracy: 0.7291 - val_loss: 0.5502 - val_accuracy: 0.7375
# Epoch 83/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5509 - accuracy: 0.7295 - val_loss: 0.5527 - val_accuracy: 0.7367
# Epoch 84/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5511 - accuracy: 0.7296 - val_loss: 0.5497 - val_accuracy: 0.7375
# Epoch 85/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5512 - accuracy: 0.7297 - val_loss: 0.5505 - val_accuracy: 0.7349
# Epoch 86/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.5508 - accuracy: 0.7291 - val_loss: 0.5501 - val_accuracy: 0.7372
# Epoch 87/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5510 - accuracy: 0.7303 - val_loss: 0.5511 - val_accuracy: 0.7375
# Epoch 88/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5505 - accuracy: 0.7295 - val_loss: 0.5521 - val_accuracy: 0.7378
# Epoch 89/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5508 - accuracy: 0.7301 - val_loss: 0.5491 - val_accuracy: 0.7372
# Epoch 90/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5508 - accuracy: 0.7298 - val_loss: 0.5507 - val_accuracy: 0.7378
# Epoch 91/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5506 - accuracy: 0.7310 - val_loss: 0.5500 - val_accuracy: 0.7362
# Epoch 92/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5506 - accuracy: 0.7303 - val_loss: 0.5503 - val_accuracy: 0.7370
# Epoch 93/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5510 - accuracy: 0.7296 - val_loss: 0.5509 - val_accuracy: 0.7380
# Epoch 94/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5507 - accuracy: 0.7285 - val_loss: 0.5501 - val_accuracy: 0.7372
# Epoch 95/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5506 - accuracy: 0.7303 - val_loss: 0.5510 - val_accuracy: 0.7378
# Epoch 96/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5508 - accuracy: 0.7298 - val_loss: 0.5499 - val_accuracy: 0.7359
# Epoch 97/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5506 - accuracy: 0.7297 - val_loss: 0.5527 - val_accuracy: 0.7372
# Epoch 98/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5509 - accuracy: 0.7299 - val_loss: 0.5505 - val_accuracy: 0.7367
# Epoch 99/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5503 - accuracy: 0.7305 - val_loss: 0.5507 - val_accuracy: 0.7375
# Epoch 100/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5504 - accuracy: 0.7308 - val_loss: 0.5534 - val_accuracy: 0.7367

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5633 - accuracy: 0.7271 - 349ms/epoch - 1ms/step
# Loss: 0.5633007884025574, Accuracy: 0.7271137237548828

# %%
# Export our model to HDF5 file
# Export our model to HDF5 file
from google.colab import files

nn_model.save('/content/Model_1.h5')
files.download('/content/Model_1.h5')
